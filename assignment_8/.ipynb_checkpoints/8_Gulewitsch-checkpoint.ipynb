# %%
# Abgabe von Leonhard Gulewitsch

# Aufgabe 21
load("//server01/lehre/ProgrammierenR/Daten/herz200.RData")

# %%
load("herz200.RData")

# %%
## a) bis d)

# %%
par(mar = c(5, 6, 5, 2))
boxplot(split(herz$BMI, herz$Geschlecht), names = c("männlich", "weiblich"))

title(main = "Boxplots des BMIs aufgeteilt\n nach Geschlecht", 
      xlab = "Geschlecht", 
      ylab = expression(BMI == frac(gamma, delta^2) ~~ "(in" ~~ frac(kg, m^2) * ")"))

BMI_limits <- list(list(18.5, "red"), list(25, "blue"), list(30, "green"))

for(limit in BMI_limits) {
  lines(c(0,3), c(limit[[1]], limit[[1]]), col = limit[[2]], lwd = 2, lty = 2)
}
# Out:
# Plot with title “Boxplots des BMIs aufgeteilt
#  nach Geschlecht”
